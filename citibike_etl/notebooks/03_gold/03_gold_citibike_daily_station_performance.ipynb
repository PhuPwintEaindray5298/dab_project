# %%
from pyspark.sql.functions import avg,count,round

# %%
catalog = dbutils.widgets.get("catalog")

# %%
df = spark.read.table(f"{catalog}.02_silver.jc_citibike")

# %%
df = df.groupBy("trip_start_date","start_station_name").agg(round(avg("trip_duration_mins"),2).alias("avg_trip_duration_mins"),count("ride_id").alias("total_trips"))

# %%
display(df)
# Out:
# DataFrame[trip_start_date: date, start_station_name: string, avg_trip_duration_mins: double, total_trips: bigint]
# /Users/phupwinteaindray/Documents/Databricks CICD/dab_project/.venv_dbc/lib/python3.11/site-packages/databricks/sdk/_widgets/__init__.py:71: UserWarning:
# To use databricks widgets interactively in your notebook, please install databricks sdk using:
# 	pip install 'databricks-sdk[notebook]'
# Falling back to default_value_only implementation for databricks widgets.
#   warnings.warn(

# %%
df.write.mode('overwrite').option('overwriteSchema','true').saveAsTable(f"{catalog}.03_gold.daily_station_performance")
